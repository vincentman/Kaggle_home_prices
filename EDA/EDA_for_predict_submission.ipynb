# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
csv_df = pd.read_csv('../train.csv')
csv_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
# Id               1460 non-null int64
# MSSubClass       1460 non-null int64
# MSZoning         1460 non-null object
# LotFrontage      1201 non-null float64
# LotArea          1460 non-null int64
# Street           1460 non-null object
# Alley            91 non-null object
# LotShape         1460 non-null object
# LandContour      1460 non-null object
# Utilities        1460 non-null object
# LotConfig        1460 non-null object
# LandSlope        1460 non-null object
# Neighborhood     1460 non-null object
# Condition1       1460 non-null object
# Condition2       1460 non-null object
# BldgType         1460 non-null object
# HouseStyle       1460 non-null object
# OverallQual      1460 non-null int64
# OverallCond      1460 non-null int64
# YearBuilt        1460 non-null int64
# YearRemodAdd     1460 non-null int64
# RoofStyle        1460 non-null object
# ...

# %%
data = pd.concat([csv_df['SalePrice'], csv_df['Exterior1st']], axis=1)
f, ax = plt.subplots(figsize=(10, 6))
fig = sns.boxplot(x='Exterior1st', y="SalePrice", data=data)
fig.axis(ymin=0, ymax=800000)
plt.xticks(rotation=90);

# %%
data = pd.concat([csv_df['SalePrice'], csv_df['KitchenQual']], axis=1)
f, ax = plt.subplots(figsize=(4, 6))
fig = sns.boxplot(x='KitchenQual', y="SalePrice", data=data)
fig.axis(ymin=0, ymax=800000);

# %%
csv_df[['BsmtUnfSF', 'SalePrice']].corr()
# Out:
#            BsmtUnfSF  SalePrice
# BsmtUnfSF   1.000000   0.214479
# SalePrice   0.214479   1.000000

# %%
plt.scatter(x=csv_df['BsmtUnfSF'], y=csv_df['SalePrice']);

# %%
data = pd.concat([csv_df['SalePrice'], csv_df['KitchenQual']], axis=1)
f, ax = plt.subplots(figsize=(4, 6))
fig = sns.boxplot(x='KitchenQual', y="SalePrice", data=data)
fig.axis(ymin=0, ymax=800000);

# %%
sns.countplot(csv_df.loc[csv_df['KitchenAbvGr']==1]['KitchenQual'])

# %%
data = pd.concat([csv_df['SalePrice'], csv_df['GarageCars']], axis=1)
f, ax = plt.subplots(figsize=(4, 6))
fig = sns.boxplot(x='GarageCars', y="SalePrice", data=data)
fig.axis(ymin=0, ymax=800000);

# %%
data = pd.concat([csv_df['GarageArea'], csv_df['GarageCars']], axis=1)
f, ax = plt.subplots(figsize=(4, 6))
fig = sns.boxplot(x='GarageCars', y="GarageArea", data=data)

# %%
csv_df[['GarageArea', 'SalePrice']].corr()
# Out:
#             GarageArea  SalePrice
# GarageArea    1.000000   0.623431
# SalePrice     0.623431   1.000000

# %%
plt.scatter(x=csv_df['GarageArea'], y=csv_df['SalePrice']);

# %%
data = pd.concat([csv_df['SalePrice'], csv_df['SaleType']], axis=1)
f, ax = plt.subplots(figsize=(6, 6))
fig = sns.boxplot(x='SaleType', y="SalePrice", data=data)
fig.axis(ymin=0, ymax=800000);

# %%
sns.countplot(csv_df.loc[csv_df['SaleCondition']=='Normal']['SaleType'])

# %%
g = sns.FacetGrid(csv_df, col='GarageType')
g = g.map(sns.distplot, "GarageArea")

# %%
data = pd.concat([csv_df['SalePrice'], csv_df['MSZoning']], axis=1)
f, ax = plt.subplots(figsize=(4, 6))
fig = sns.boxplot(x='MSZoning', y="SalePrice", data=data)
fig.axis(ymin=0, ymax=800000);

# %%
sns.countplot(csv_df.loc[csv_df['MSSubClass']==30]['MSZoning'])

# %%
sns.countplot(csv_df.loc[csv_df['MSSubClass']==20]['MSZoning'])

# %%
sns.countplot(csv_df.loc[csv_df['MSSubClass']==70]['MSZoning'])

# %%
data = pd.concat([csv_df['SalePrice'], csv_df['Utilities']], axis=1)
f, ax = plt.subplots(figsize=(4, 6))
fig = sns.boxplot(x='Utilities', y="SalePrice", data=data)
fig.axis(ymin=0, ymax=800000);

# %%
sns.countplot(csv_df['Utilities'])

# %%
data = pd.concat([csv_df['SalePrice'], csv_df['BsmtFullBath']], axis=1)
f, ax = plt.subplots(figsize=(4, 6))
fig = sns.boxplot(x='BsmtFullBath', y="SalePrice", data=data)
fig.axis(ymin=0, ymax=800000);

# %%
data = pd.concat([csv_df['SalePrice'], csv_df['BsmtHalfBath']], axis=1)
f, ax = plt.subplots(figsize=(4, 6))
fig = sns.boxplot(x='BsmtHalfBath', y="SalePrice", data=data)
fig.axis(ymin=0, ymax=800000);

# %%
data = pd.concat([csv_df['SalePrice'], csv_df['Functional']], axis=1)
f, ax = plt.subplots(figsize=(6, 6))
fig = sns.boxplot(x='Functional', y="SalePrice", data=data)
fig.axis(ymin=0, ymax=800000);

# %%
csv_df['Utilities'].value_counts()
# Out:
# AllPub    1459
# NoSeWa       1
# Name: Utilities, dtype: int64

# %%
csv_df['Functional'].value_counts()
# Out:
# Typ     1360
# Min2      34
# Min1      31
# Mod       15
# Maj1      14
# Maj2       5
# Sev        1
# Name: Functional, dtype: int64
