# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np 
from scipy.stats import norm 
from sklearn.preprocessing import StandardScaler 
from scipy import stats
# %matplotlib inline

# %%
df_train = pd.read_csv('train.csv')

# %%
df_train.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
df_train.columns.size
# Out:
# 81

# %%
df_train['SalePrice'].describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
sns.distplot(df_train['SalePrice'])

# %%
print("SalePrice Skewness: %f" % df_train['SalePrice'].skew())
print("SalePrice Kurtosis: %f" % df_train['SalePrice'].kurt())
# Out:
# SalePrice Skewness: 1.882876
# SalePrice Kurtosis: 6.536282

# %% [markdown]
# ## SalePrice 與 GrLivArea 散點圖

# %%
data = pd.concat([df_train['SalePrice'], df_train['GrLivArea']], axis=1)
data.plot.scatter(x='GrLivArea', y='SalePrice', ylim=(0,800000));

# %% [markdown]
# ## SalePrice 與 TotalBsmtSF 散點圖

# %%
data = pd.concat([df_train['SalePrice'], df_train['TotalBsmtSF']], axis=1)
data.plot.scatter(x='TotalBsmtSF', y='SalePrice', ylim=(0,800000));

# %% [markdown]
# ## SalePrice 與 OverallQual 箱形圖

# %%
data = pd.concat([df_train['SalePrice'], df_train['OverallQual']], axis=1)
f, ax = plt.subplots(figsize=(8, 6))
fig = sns.boxplot(x='OverallQual', y="SalePrice", data=data)
fig.axis(ymin=0, ymax=800000);

# %% [markdown]
# ## SalePrice 與 YearBuilt 箱形圖

# %%
data = pd.concat([df_train['SalePrice'], df_train['YearBuilt']], axis=1)
f, ax = plt.subplots(figsize=(16, 8))
fig = sns.boxplot(x='YearBuilt', y="SalePrice", data=data)
fig.axis(ymin=0, ymax=800000);plt.xticks(rotation=90);

# %% [markdown]
# ## 全部變量的相關係數矩陣

# %%
corrmat = df_train.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmax=.8, square=True)

# %% [markdown]
# ## SalePrice 的相關係數矩陣

# %%
k = 10 #number ofvariables for heatmap
cols = corrmat.nlargest(k, 'SalePrice')['SalePrice'].index
cm = np.corrcoef(df_train[cols].values.T)
sns.set(font_scale=1.25)
hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 10}, 
yticklabels=cols.values, xticklabels=cols.values)

# %% [markdown]
# ## SalePrice 和相關變量之間的散點圖

# %%
sns.set()
cols = ['SalePrice', 'OverallQual', 'GrLivArea','GarageCars', 'TotalBsmtSF', 'FullBath', 'YearBuilt']
sns.pairplot(df_train[cols], size = 2.5)

# %% [markdown]
# ## 觀察 missing value 的欄位

# %%
total= df_train.isnull().sum().sort_values(ascending=False)
percent = (df_train.isnull().sum()/df_train.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total','Percent'])
missing_data.head(20)
# Out:
#               Total   Percent
# PoolQC         1453  0.995205
# MiscFeature    1406  0.963014
# Alley          1369  0.937671
# Fence          1179  0.807534
# FireplaceQu     690  0.472603
# LotFrontage     259  0.177397
# GarageCond       81  0.055479
# GarageType       81  0.055479
# GarageYrBlt      81  0.055479
# GarageFinish     81  0.055479
# GarageQual       81  0.055479
# BsmtExposure     38  0.026027
# BsmtFinType2     38  0.026027
# BsmtFinType1     37  0.025342
# BsmtCond         37  0.025342
# BsmtQual         37  0.025342
# MasVnrArea        8  0.005479
# MasVnrType        8  0.005479
# Electrical        1  0.000685
# Utilities         0  0.000000

# %% [markdown]
# ## 1. 刪除缺值樣本數超過1個的欄位　2. 刪除Electrical欄位缺值的樣本

# %%
df_train= df_train.drop((missing_data[missing_data['Total'] > 1]).index,1)
df_train= df_train.drop(df_train.loc[df_train['Electrical'].isnull()].index)
df_train.isnull().sum().max() #justchecking that there's no missing data missing...
# Out:
# 0

# %%
saleprice_scaled = StandardScaler().fit_transform(df_train['SalePrice'][:, np.newaxis])
low_range = saleprice_scaled[saleprice_scaled[:, 0].argsort()][:10]
high_range = saleprice_scaled[saleprice_scaled[:, 0].argsort()][-10:]
print('outer range (low) of the distribution:')
print(low_range)
print('\nouter range (high) of the distribution:')
print(high_range)
# Out:
# outer range (low) of the distribution:
# [[-1.83820775]
#  [-1.83303414]
#  [-1.80044422]
#  [-1.78282123]
#  [-1.77400974]
#  [-1.62295562]
#  [-1.6166617 ]
#  [-1.58519209]
#  [-1.58519209]
#  [-1.57269236]]
#
# outer range (high) of the distribution:
# [[ 3.82758058]
#  [ 4.0395221 ]
#  [ 4.49473628]
#  [ 4.70872962]
#  [ 4.728631  ]
#  [ 5.06034585]
#  [ 5.42191907]
#  [ 5.58987866]
#  [ 7.10041987]
#  [ 7.22629831]]
# C:\Users\Vincent\Anaconda3\envs\python3\lib\site-packages\sklearn\utils\validation.py:444: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %% [markdown]
# ## 偵測離群的 GrLivArea 值很高的數據

# %%
data = pd.concat([df_train['SalePrice'], df_train['GrLivArea']], axis=1)
data.plot.scatter(x='GrLivArea', y='SalePrice', ylim=(0,800000))

# %%
print("GrLivArea Skewness: %f" % df_train['GrLivArea'].skew())
print("GrLivArea Kurtosis: %f" % df_train['GrLivArea'].kurt())
# Out:
# GrLivArea Skewness: 1.365701
# GrLivArea Kurtosis: 4.889432

# %% [markdown]
# ## 刪除離群的 GrLivArea 值很高的數據

# %%
ids = df_train.sort_values(by = 'GrLivArea',ascending = False)[:2]['Id']
df_train = df_train.drop(ids.index)

# %% [markdown]
# ## SalePrice：繪製直方圖和正態概率圖

# %%
sns.distplot(df_train['SalePrice'], fit=norm)
fig = plt.figure()
res = stats.probplot(df_train['SalePrice'], plot=plt)

# %% [markdown]
# ## 將 SalePrice 做對數變換

# %%
df_train['SalePrice']= np.log(df_train['SalePrice'])

# %% [markdown]
# ## SalePrice：繪製直方圖和正態概率圖(對數變換後)

# %%
sns.distplot(df_train['SalePrice'], fit=norm);
fig = plt.figure()
res = stats.probplot(df_train['SalePrice'], plot=plt)

# %% [markdown]
# ## GrLivArea：繪製直方圖和正態概率圖

# %%
sns.distplot(df_train['GrLivArea'], fit=norm);
fig = plt.figure()
res = stats.probplot(df_train['GrLivArea'], plot=plt)

# %% [markdown]
# ## 將 GrLivArea 做對數變換

# %%
df_train['GrLivArea']= np.log(df_train['GrLivArea'])

# %% [markdown]
# ## GrLivArea：繪製直方圖和正態概率圖(對數變換後)

# %%
sns.distplot(df_train['GrLivArea'], fit=norm)
fig = plt.figure()
res = stats.probplot(df_train['GrLivArea'], plot=plt)

# %% [markdown]
# ## TotalBsmtSF：繪製直方圖和正態概率圖

# %%
sns.distplot(df_train['TotalBsmtSF'],fit=norm);
fig = plt.figure()
res = stats.probplot(df_train['TotalBsmtSF'],plot=plt)

# %%
df_train['HasBsmt'] = 0
df_train.loc[df_train['TotalBsmtSF']>0, 'HasBsmt'] = 1

# %% [markdown]
# ## 將 TotalBsmtSF 做對數變換

# %%
df_train['TotalBsmtSF']= np.log(df_train['TotalBsmtSF'])

# %%
sns.distplot(df_train['TotalBsmtSF'], fit=norm);
fig = plt.figure()
res = stats.probplot(df_train['TotalBsmtSF'], plot=plt)
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# <ipython-input-67-69ef62768cbd> in <module>()
# ----> 1 sns.distplot(df_train['TotalBsmtSF'], fit=norm);
#       2 fig = plt.figure()
#       3 res = stats.probplot(df_train['TotalBsmtSF'], plot=plt)
#
# ~\Anaconda3\envs\python3\lib\site-packages\seaborn\distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     206     if hist:
#     207         if bins is None:
# --> 208             bins = min(_freedman_diaconis_bins(a), 50)
#     209         hist_kws.setdefault("alpha", 0.4)
#     210         hist_kws.setdefault("normed", norm_hist)
#
# ~\Anaconda3\envs\python3\lib\site-packages\seaborn\distributions.py in _freedman_diaconis_bins(a)
#      32         return int(np.sqrt(a.size))
#      33     else:
# ...

# %% [markdown]
# ## SalePrice 和 GrLivArea 同方差性(使用散點圖)

# %%
plt.scatter(df_train['GrLivArea'],df_train['SalePrice']);

# %% [markdown]
# ## SalePrice with TotalBsmtSF 同方差性(使用散點圖)

# %%
plt.scatter(df_train[df_train['TotalBsmtSF']>0]['TotalBsmtSF'], df_train[df_train['TotalBsmtSF']>0]['SalePrice']);
